# %%
import pandas as pd
import requests

# %%
url = "https://imdb-top-100-movies.p.rapidapi.com/"

headers = {
	"x-rapidapi-key": "",
	"x-rapidapi-host": "imdb-top-100-movies.p.rapidapi.com"
}

# Step 1: Fetch data from API
response = requests.get(url, headers = headers)

# Step 2: Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse JSON response

    # Step 3: Convert JSON data to DataFrame
    if isinstance(data, list):
        df = pd.DataFrame(data)
        print("Data is obtained")
    else:
        print("Unexpected data format:", type(data))

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Data is obtained

# %%
df
# Out:
#                          title  \
# rank
# 1     The Shawshank Redemption
# 2                The Godfather
# 3              The Dark Knight
# 4        The Godfather Part II
# 5                 12 Angry Men
# ...                        ...
# 96              Reservoir Dogs
# 97                       Ikiru
# 98          Lawrence of Arabia
# 99                Citizen Kane
# 100                          M
#
#                                             description  \
# rank
# 1     Two imprisoned men bond over a number of years...
# 2     The aging patriarch of an organized crime dyna...
# 3     When the menace known as the Joker wreaks havo...
# 4     The early life and career of Vito Corleone in ...
# 5     The jury in a New York City murder trial is fr...
# ...                                                 ...
# 96    When a simple jewelry heist goes horribly wron...
# 97    A bureaucrat tries to find meaning in his life...
# 98    The story of T.E. Lawrence, the English office...
# ...

# %%
df.shape
# Out:
# (100, 11)

# %%
df.to_csv('movies.csv')

# %%
ourDf = pd.read_csv('movies.csv')

# %%
ourDf
# Out:
#     rank                     title  \
# 0      1  The Shawshank Redemption
# 1      2             The Godfather
# 2      3           The Dark Knight
# 3      4     The Godfather Part II
# 4      5              12 Angry Men
# ..   ...                       ...
# 95    96            Reservoir Dogs
# 96    97                     Ikiru
# 97    98        Lawrence of Arabia
# 98    99              Citizen Kane
# 99   100                         M
#
#                                           description  \
# 0   Two imprisoned men bond over a number of years...
# 1   The aging patriarch of an organized crime dyna...
# 2   When the menace known as the Joker wreaks havo...
# 3   The early life and career of Vito Corleone in ...
# 4   The jury in a New York City murder trial is fr...
# ..                                                ...
# 95  When a simple jewelry heist goes horribly wron...
# 96  A bureaucrat tries to find meaning in his life...
# ...

# %%
ourDf.head()
# Out:
#    rank                     title  \
# 0     1  The Shawshank Redemption
# 1     2             The Godfather
# 2     3           The Dark Knight
# 3     4     The Godfather Part II
# 4     5              12 Angry Men
#
#                                          description  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                                            big_image  \
# ...

# %%
df = pd.read_csv('movies.csv', index_col = 'rank')
df
# Out:
#                          title  \
# rank
# 1     The Shawshank Redemption
# 2                The Godfather
# 3              The Dark Knight
# 4        The Godfather Part II
# 5                 12 Angry Men
# ...                        ...
# 96              Reservoir Dogs
# 97                       Ikiru
# 98          Lawrence of Arabia
# 99                Citizen Kane
# 100                          M
#
#                                             description  \
# rank
# 1     Two imprisoned men bond over a number of years...
# 2     The aging patriarch of an organized crime dyna...
# 3     When the menace known as the Joker wreaks havo...
# 4     The early life and career of Vito Corleone in ...
# 5     The jury in a New York City murder trial is fr...
# ...                                                 ...
# 96    When a simple jewelry heist goes horribly wron...
# 97    A bureaucrat tries to find meaning in his life...
# 98    The story of T.E. Lawrence, the English office...
# ...

# %%
new_df = pd.read_csv('movies.csv', usecols = ['rank','title','description','genre','rating','year','image'], index_col='rank')

# %%
new_df.head()
# Out:
#                          title  \
# rank
# 1     The Shawshank Redemption
# 2                The Godfather
# 3              The Dark Knight
# 4        The Godfather Part II
# 5                 12 Angry Men
#
#                                             description  \
# rank
# 1     Two imprisoned men bond over a number of years...
# 2     The aging patriarch of an organized crime dyna...
# 3     When the menace known as the Joker wreaks havo...
# 4     The early life and career of Vito Corleone in ...
# 5     The jury in a New York City murder trial is fr...
#
#                                                   image  \
# rank
# 1     https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2     https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4     https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5     https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                              genre  rating  year
# rank
# ...

# %%
new_df.shape
# Out:
# (100, 6)
